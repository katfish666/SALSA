# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
import warnings
warnings.filterwarnings("ignore")

import os
import pandas as pd
import numpy as np
ddir = 'data/'
df = pd.read_csv(os.path.join(ddir,'play_dataset_10to20.csv'),usecols=['smiles'])
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# <style>.container { width:95% !important; }</style>

# %%
from data_utils import *

t = tokenize(df.smiles)
# print(t)

def get_singular_smiles(smiles):
    smiles = smiles.replace('Br','R')
    smiles = smiles.replace('Cl','L')
    return smiles

from collections import Counter

df['smiles_singular'] = df.smiles.apply(lambda x: get_singular_smiles(x))
vocab = ''.join(df.smiles_singular)
(Counter(vocab))
# Out:
# Counter({'N': 13227,
#          'C': 62429,
#          '(': 16291,
#          '=': 10980,
#          'O': 16972,
#          ')': 16291,
#          'c': 45021,
#          '1': 22870,
#          'l': 1342,
#          '#': 820,
#          '[': 1568,
#          '-': 443,
#          ']': 1568,
#          '+': 363,
#          'S': 2787,
#          'n': 7120,
#          'F': 794,
#          'R': 580,
#          's': 974,
#          'P': 334,
#          'H': 1013,
#          'I': 239,
#          'o': 505,
#          '2': 6109,
#          '3': 132,
#          '4': 4,
#          '5': 2})

# %%
from rdkit.Chem.rdchem import RWMol, Atom, Bond, BondType

df = df[:10]
df
# Out:
#         smiles smiles_singular
# 0   NCCCC(=O)O      NCCCC(=O)O
# 1    Nc1ccccc1       Nc1ccccc1
# 2    ClCCNCCCl         LCCNCCL
# 3    N#CN1CCC1       N#CN1CCC1
# 4    Cc1ccccc1       Cc1ccccc1
# 5   NCc1ccccc1      NCc1ccccc1
# 6   NCCNCCNCCN      NCCNCCNCCN
# 7   OCc1ccccc1      OCc1ccccc1
# 8    CN1CCNCC1       CN1CCNCC1
# 9  [N-]=[N+]=N     [N-]=[N+]=N
