# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import warnings
warnings.filterwarnings("ignore")

import os
import pandas as pd
import sys
sys.path.insert(0, '/home/kat/Repos/SALSA/')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from rdkit.Chem import PandasTools
import rdkit
# print(rdkit.__version__)

def show_df(df):
    print(df.shape)
    return HTML(df[:5].to_html(notebook=True))

fname = 'data/dye_data/Absorption/Continuous/'
fname = fname + 'wavelength-max-absorption_continuous_380-to-700-\
nm_ClCCl-solvent_deep4chem-and-smfluo-databases.sdf'

df = PandasTools.LoadSDF(fname,smilesName='SMILES',molColName='Molecule',
                          includeFingerprints=False, removeHs=False, strictParsing=False)

df = df.drop(['ID','Solvent','Database','InChIKey','Molecule'],axis=1,errors='ignore')
df
# Out:
#      Compound_name Outcome                                             SMILES
# 0             9927   436.0  CC(C)(C)c1ccc(-c2ccc(-c3ccc(N(c4ccccc4)c4ccccc...
# 1            15654   403.0  CCC1(CC)c2ccccc2-c2ccc(C#Cc3ccc4ccc5cccc6ccc3c...
# 2             7417   430.0  CN(C)c1ccc(C2=Nc3sc4cc(Cl)ccc4[n+]3[B-](F)(F)O...
# 3             4772   473.0  c1ccc(-c2ccc3c4ccc(-c5ccccc5)c5c(-c6ccccc6)ccc...
# 4            13605   467.0    CCN(CC)/C(C)=N\c1ccc2c3c(cccc13)C(=O)c1ccccc1-2
# ...            ...     ...                                                ...
# 1545          4990   535.0  COc1ccc(C2=C(C)C3=C(c4c(-c5ccccn5)nc5ccccn45)c...
# 1546         16759   386.0      CCCCCCCCCCCCCCCC[n+]1ccc(/C=C(\C)c2ccccc2)cc1
# 1547         17804   616.0  CCc1c(C)c2n(c1C)[B-](F)(F)[N+]1=C(c3ccc[nH]3)c...
# 1548         12551   467.0  CCCCC(CC)Cn1c2cc(C#N)ccc2c2ccc(C#Cc3cc(C#Cc4cc...
# 1549         12832   698.0  COc1ccc2cc(C3=[N+]4C(=Nc5c(-c6ccc7ccccc7c6)c(B...
#
# [1550 rows x 3 columns]

# %%
from dyes_utils import wav2RGB, rgb2hex

df['RGB'] = df.Outcome.apply(lambda x: wav2RGB(x))
df['hex'] = df.RGB.apply(lambda x: rgb2hex(x))
df
# Out:
#      Compound_name Outcome                                             SMILES  \
# 0             9927   436.0  CC(C)(C)c1ccc(-c2ccc(-c3ccc(N(c4ccccc4)c4ccccc...
# 1            15654   403.0  CCC1(CC)c2ccccc2-c2ccc(C#Cc3ccc4ccc5cccc6ccc3c...
# 2             7417   430.0  CN(C)c1ccc(C2=Nc3sc4cc(Cl)ccc4[n+]3[B-](F)(F)O...
# 3             4772   473.0  c1ccc(-c2ccc3c4ccc(-c5ccccc5)c5c(-c6ccccc6)ccc...
# 4            13605   467.0    CCN(CC)/C(C)=N\c1ccc2c3c(cccc13)C(=O)c1ccccc1-2
# ...            ...     ...                                                ...
# 1545          4990   535.0  COc1ccc(C2=C(C)C3=C(c4c(-c5ccccn5)nc5ccccn45)c...
# 1546         16759   386.0      CCCCCCCCCCCCCCCC[n+]1ccc(/C=C(\C)c2ccccc2)cc1
# 1547         17804   616.0  CCc1c(C)c2n(c1C)[B-](F)(F)[N+]1=C(c3ccc[nH]3)c...
# 1548         12551   467.0  CCCCC(CC)Cn1c2cc(C#N)ccc2c2ccc(C#Cc3cc(C#Cc4cc...
# 1549         12832   698.0  COc1ccc2cc(C3=[N+]4C(=Nc5c(-c6ccc7ccccc7c6)c(B...
#
# ...

# %%
import copy

df_style = copy.deepcopy(df)
df_style[:10].style.applymap(lambda x:"background-color: %s"%x, subset=['hex'])
# Out:
# <style type="text/css">
# #T_69fd0_row0_col4 {
#   background-color: #1100ff;
# }
# #T_69fd0_row1_col4 {
#   background-color: #6e00b3;
# }
# #T_69fd0_row2_col4 {
#   background-color: #2a00ff;
# }
# #T_69fd0_row3_col4 {
#   background-color: #00a8ff;
# }
# #T_69fd0_row4_col4 {
#   background-color: #0089ff;
# }
# #T_69fd0_row5_col4 {
#   background-color: #ff5a00;
# }
# #T_69fd0_row6_col4 {
#   background-color: #6e00a5;
# }
# #T_69fd0_row7_col4 {
#   background-color: #6700d6;
# }
# #T_69fd0_row8_col4 {
#   background-color: #3b00ff;
# }
# #T_69fd0_row9_col4 {
#   background-color: #3700ff;
# }
# </style>
# <table id="T_69fd0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Compound_name</th>
#       <th class="col_heading level0 col1" >Outcome</th>
#       <th class="col_heading level0 col2" >SMILES</th>
#       <th class="col_heading level0 col3" >RGB</th>
#       <th class="col_heading level0 col4" >hex</th>
# ...

# %%
import colorsys

def get_hsv(hexrgb):
    hexrgb = hexrgb.lstrip("#")   # in case you have Web color specs
    r, g, b = (int(hexrgb[i:i+2], 16) / 255.0 for i in range(0,5,2))
    return colorsys.rgb_to_hsv(r, g, b)

df['HSV'] = df.hex.apply(lambda x: get_hsv(x))
df = df.sort_values(by='HSV')
# df.to_csv('eastman_dye_data_rgb_hex.csv',index=False)
# t = pd.read_csv('eastman_dye_data_rgb_hex.csv')
# t

# %%
from rdkit.Chem import PandasTools

# # # # # # # # # #
N = 130
# # # # # # # # # #
df_samp = df.sample(N)

PandasTools.AddMoleculeColumnToFrame(df_samp,'SMILES','mol',includeFingerprints=False)

df_samp.sort_values(by='HSV',inplace=True)
df_style = copy.deepcopy(df_samp)
df_style = df_style[['mol','hex']]
# df_style
df_style.style.applymap(lambda x:"background-color: %s"%x, subset=['hex'])
# Out:
# <style type="text/css">
# #T_4a472_row0_col1, #T_4a472_row1_col1, #T_4a472_row2_col1, #T_4a472_row3_col1, #T_4a472_row4_col1, #T_4a472_row5_col1, #T_4a472_row6_col1, #T_4a472_row7_col1, #T_4a472_row8_col1, #T_4a472_row9_col1, #T_4a472_row10_col1, #T_4a472_row11_col1 {
#   background-color: #ff0000;
# }
# #T_4a472_row12_col1 {
#   background-color: #ff0700;
# }
# #T_4a472_row13_col1 {
#   background-color: #ff1300;
# }
# #T_4a472_row14_col1 {
#   background-color: #ff1f00;
# }
# #T_4a472_row15_col1, #T_4a472_row16_col1 {
#   background-color: #ff4a00;
# }
# #T_4a472_row17_col1 {
#   background-color: #ff7100;
# }
# #T_4a472_row18_col1 {
#   background-color: #ff8500;
# }
# #T_4a472_row19_col1, #T_4a472_row20_col1 {
#   background-color: #ff9500;
# }
# #T_4a472_row21_col1 {
#   background-color: #ff9900;
# }
# #T_4a472_row22_col1 {
#   background-color: #ffcc00;
# }
# #T_4a472_row23_col1, #T_4a472_row24_col1 {
#   background-color: #ffeb00;
# }
# #T_4a472_row25_col1 {
# ...

# %%
# # # # # # # # # #
N = 64
# # # # # # # # # #
df_samp = df.sample(N)

PandasTools.AddMoleculeColumnToFrame(df_samp,'SMILES','mol',includeFingerprints=False)

df_samp.sort_values(by='HSV',inplace=True)
df_style = copy.deepcopy(df_samp)
df_style = df_style[['mol','hex','Outcome']]
# df_style
df_style.style.applymap(lambda x:"background-color: %s"%x, subset=['hex'])
# Out:
# <style type="text/css">
# #T_c4b74_row0_col1, #T_c4b74_row1_col1, #T_c4b74_row2_col1, #T_c4b74_row3_col1, #T_c4b74_row4_col1, #T_c4b74_row5_col1, #T_c4b74_row6_col1 {
#   background-color: #ff0000;
# }
# #T_c4b74_row7_col1 {
#   background-color: #ff0700;
# }
# #T_c4b74_row8_col1 {
#   background-color: #ff0f00;
# }
# #T_c4b74_row9_col1, #T_c4b74_row10_col1 {
#   background-color: #ff2f00;
# }
# #T_c4b74_row11_col1 {
#   background-color: #ff3600;
# }
# #T_c4b74_row12_col1 {
#   background-color: #ff6200;
# }
# #T_c4b74_row13_col1 {
#   background-color: #ff6900;
# }
# #T_c4b74_row14_col1 {
#   background-color: #ff6d00;
# }
# #T_c4b74_row15_col1 {
#   background-color: #ff9500;
# }
# #T_c4b74_row16_col1 {
#   background-color: #ffd300;
# }
# #T_c4b74_row17_col1 {
#   background-color: #bdff00;
# }
# #T_c4b74_row18_col1 {
#   background-color: #abff00;
# }
# #T_c4b74_row19_col1 {
#   background-color: #95ff00;
# }
# #T_c4b74_row20_col1 {
#   background-color: #91ff00;
# }
# ...
