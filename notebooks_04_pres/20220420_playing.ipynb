# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
import sys
sys.path.insert(0, '/home/kat/Repos/SALSA/')
# Out:
# <style>.container { width:95% !important; }</style>

# %%
from rdkit.Chem import AllChem
from rdkit import Chem, Geometry
from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import rdFMCS
from rdkit.Chem.Draw import rdDepictor
rdDepictor.SetPreferCoordGen(True)

# %%
def sm_and_mol(sm):
    mol = Chem.MolFromSmiles(sm)
    sm = Chem.MolToSmiles(mol)
    display(sm,mol)

# %%
sm = 'CC(CC1=CC=CC=C1)N'
sm_and_mol(sm)
# Out:
# 'CC(N)Cc1ccccc1'

# %%
sm = 'CC(CC1=CC=CC=C1)NC'
sm_and_mol(sm)
# Out:
# 'CNC(C)Cc1ccccc1'

# %%
sm = 'CC(CC1=CC2=C(C=C1)OCO2)N'
sm_and_mol(sm)
# Out:
# 'CC(N)Cc1ccc2c(c1)OCO2'

# %%
sm = 'CC(CC1=CC2=C(C=C1)OCO2)N'
sm_and_mol(sm)
# Out:
# 'CC(N)Cc1ccc2c(c1)OCO2'

# %%
sm = 'C1=CC(=C(C=C1CCN)O)O'
sm_and_mol(sm)
# Out:
# 'NCCc1ccc(O)c(O)c1'

# %%
sm = 'C1=CC(=C(C=C1CCC)N)O'
sm_and_mol(sm)
# Out:
# 'CCCc1ccc(O)c(N)c1'

# %%
sm = 'CN1C2CCC1C(C(C2)OC(=O)C3=CC=CC=C3)C(=O)OC'
sm_and_mol(sm)
# Out:
# 'COC(=O)C1C(OC(=O)c2ccccc2)CC2CCC1N2C'

# %%
sm = 'CC(=O)NC1=CC=C(C=C1)O'
sm_and_mol(sm)
# Out:
# 'CC(=O)Nc1ccc(O)cc1'

# %%
sm = 'CC(=O)NC1=CC=C(C=C1)'
sm_and_mol(sm)
# Out:
# 'CC(=O)Nc1ccccc1'
