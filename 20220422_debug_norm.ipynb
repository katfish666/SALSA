# %%
import numpy as np
import math
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
x = torch.randn(5,32)
y = F.normalize(x, p=2, dim=-1)
y.shape
# Out:
# torch.Size([5, 32])

# %%
(y*y).sum(-1)
# Out:
# tensor([1.0000, 1.0000, 1.0000, 1.0000, 1.0000])

# %%
y
# Out:
# tensor([[ -22.1551,   11.4658,  -68.0295,  -79.1150, -161.0137,  -27.8046,
#          -128.2829,   97.6349,  -62.3282,    8.1914,   10.4240,  -13.5152,
#           -65.8393,   92.9459,  101.6272,  -19.9047,   -7.1604,  -31.4264,
#          -112.2122,   19.4876,  -33.2093,   94.6608,  103.7737, -219.1345,
#           141.2781,  102.4806,  -33.1131,  -94.7961,  160.2579,  -68.4177,
#           110.3934,  -83.7345],
#         [  77.7911,  -67.6712,  104.6342,  -93.4387,   40.8501,  107.9329,
#           195.5328,   42.5693,   84.6965,   -7.5364,  -25.3260,   60.8507,
#           -54.0986,  -36.3137,   12.3138,  109.2391, -143.1344,   71.5040,
#           -61.9745,  111.3405,  -30.6185,   28.6467,  -79.2577,  -34.0523,
#            64.2047,   -4.9439,  -55.9648,  -35.1431,    9.4330, -110.1168,
#            91.7516,  139.7410],
#         [  66.5190,  108.7377, -175.0764,  -86.6490,   12.1850,    9.0017,
#            76.1880,  115.9470,  -22.2021,   37.9545,  256.4062,  177.6599,
# ...
