# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
import warnings
warnings.filterwarnings("ignore")

import os
import pandas as pd
import sys
sys.path.insert(0, '/home/kat/Repos/SALSA/')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from tqdm.notebook import tqdm
from rdkit import Chem

def get_atom_cnts(smileses):
    '''
    Given a list of SMILES strings, return dictionary of atom counts
    '''
    atom_to_cnt = {}
    
    for smiles in tqdm(smileses, total=len(smileses)):
        mol = Chem.MolFromSmiles(smiles)

        for atom in mol.GetAtoms():
            atom_type = atom.GetSymbol()
            if atom_type not in atom_to_cnt.keys():
                atom_to_cnt[atom_type] = 0
            else:
                atom_to_cnt[atom_type] += 1
            
    return atom_to_cnt

df = pd.read_csv('data/chembl_valid_10to30atoms.csv')
atom_to_cnt = get_atom_cnts(df.smiles)
# Out:
#   0%|          | 0/999783 [00:00<?, ?it/s]

# %%
atom_to_cnt
# Out:
# {'N': 2696053,
#  'C': 17363219,
#  'O': 2544692,
#  'S': 393100,
#  'I': 7265,
#  'Br': 56161,
#  'Cl': 221403,
#  'F': 272005,
#  'P': 14095,
#  'B': 23}
