# %%
# %load_ext autoreload
# %autoreload 2
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>.container { width:95% !important; }</style>

# %%
from contra_seq_dataset import ContraSeqDataset

anc_path = 'model_dataset/anchor_smiles.csv'
aug_path = 'model_dataset/augmented_smiles.csv'

dataset = ContraSeqDataset(anc_path, aug_path)

samp = dataset.__getitem__(0)
print(samp['anchor'])
print(samp['augs'][:4])
# Out:
# tensor([11, 22, 27,  5, 27, 27, 27,  6, 27, 27, 27, 27, 27,  6, 27,  5, 13, 24,
#         24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24,
#         24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24,
#         24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24,
#         24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24,
#         24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24,
#         24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24])
# tensor([[11, 14, 27,  5, 27, 27, 27, 27,  6, 27, 27,  1, 22,  2, 27, 27, 27,  5,
#           6, 13, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24,
#          24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24,
#          24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24,
#          24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24, 24,
# ...

# %%
smi_augs = dataset.convert_vec_to_smi(samp['augs'], snip=True)
print(smi_augs)
# Out:
# ['Cc1cccc2cc(Br)ccc12', 'Clc1ccc2cc(Br)ccc2c1', 'Cc1c(Br)ccc2ccccc12', 'Cc1ccc2ccc(Br)cc2c1', 'Nc1cc(Br)cc2ccccc12', 'Cc1cccc2ccc(Br)cc12', 'Cc1cc2ccccc2cc1Br']

# %%
smi_augs = dataset.convert_vec_to_smi(samp['augs'], snip=False)
print(smi_augs)
# Out:
# ['<O=C1NC(c2ccccc2F)SC1O>XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX', '<Cc1cccc(F)c1C1NC(=O)CS1>XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX', '<CC1(c2ccccc2F)NC(=O)CS1>XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX', '<Cc1ccc(C2NC(=O)CS2)c(F)c1>XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX', '<Cc1ccc(F)c(C2NC(=O)CS2)c1>XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX', '<Cc1cccc(C2NC(=O)CS2)c1F>XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX', '<O=C1C[SH](O)C(c2ccccc2F)N1>XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX', '<CN1C(=O)CSC1c1ccccc1F>XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX
# ...
